# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('doubleprint.png')
image = image[65:330,235:1085]
#cv2.waitKey(0)
  
# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  
# Find Canny edges
edged = cv2.Canny(gray, 100, 400)
#cv2.waitKey(0)
  
# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#plt.imshow( edged)
#cv2.waitKey(0)
for cnt in contours :
    area = cv2.contourArea(cnt)
   
    # Shortlisting the regions based on there area.
    if area < 60: 
        approx = cv2.approxPolyDP(cnt, 0.00009 * cv2.arcLength(cnt, True), True)
   
        # Checking if the no. of sides of the selected region is 7.
        if(len(approx) == 5): 
            cv2.drawContours(image, [approx], 0, (0, 0, 255), 1)
print(area)
print(len(approx))
print("Number of Contours found = " + str(len(contours)))
  
# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (255, 0, 0), 3)
  
plt.imshow( image, cmap = 'gray')
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# 43.5
# 462
# Number of Contours found = 44

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('doubleprint.png')
image = image[65:330,235:1085]
plt.imshow( image)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('printnotsharp.png')
#image = image[65:330,235:1085]
#cv2.waitKey(0)
  
# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  
# Find Canny edges
edged = cv2.Canny(gray, 100, 400)
#cv2.waitKey(0)
  
# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#plt.imshow( edged)
#cv2.waitKey(0)
for cnt in contours :
    area = cv2.contourArea(cnt)
   
    # Shortlisting the regions based on there area.
    if area < 60: 
        approx = cv2.approxPolyDP(cnt, 0.00009 * cv2.arcLength(cnt, True), True)
   
        # Checking if the no. of sides of the selected region is 7.
        if(len(approx) == 5): 
            cv2.drawContours(image, [approx], 0, (0, 0, 255), 1)
print(area)
print(len(approx))
print("Number of Contours found = " + str(len(contours)))
  
# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (255, 0, 0), 3)
  
plt.imshow( image, cmap = 'gray')
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# 27.0
# 97
# Number of Contours found = 22
