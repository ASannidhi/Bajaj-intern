# %%
import cv2 as cv
import os

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img_path1=r"C:\Users\asannidhi\Desktop\pad printing-20220623T083349Z-001\pad printing\LH sp ok 5\20220613_105610.jpg"
img_path2=r"C:\Users\asannidhi\Downloads\mask.png"
img1= cv.imread(img_path1, cv.IMREAD_COLOR)
img2= cv.imread(img_path2)
bitwiseAnd = cv.bitwise_or(img1, img2)
#bitwiseNot = cv.bitwise(bitwiseAnd)
plt.imshow(bitwiseAnd)

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
edged = cv.Canny(gray, 40, 200)
#plt.imshow(edged)
edgecopy = edged.copy()
contours, _ = cv.findContours(edgecopy, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
#plt.imshow(edgecopy)
mask = np.zeros(img.shape, np.uint8)
cv.drawContours(mask, contours, -1, (255,255,255),3)
plt.imshow(mask)

# %%
import cv2 as cv
import os

img_path = r"C:\Users\asannidhi\Desktop\LH sp ok 5"
od_images = r"C:\Users\asannidhi\Desktop\maskimg"
for img,od in os.listdir(img_path), os.listdir(od_images):

    image = cv.imread(img_path+"\\"+img, cv.IMREAD_GRAYSCALE)
    od = cv.imread(od_images+"\\"+od, cv.IMREAD_GRAYSCALE)

    other = cv.bitwise_not(od)
    res =  cv.bitwise_and(image,image,mask = od)

    cv.imwrite( 'Desktop/maskimg/' + img+ '_masking.jpg', res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       4 img_path = r"C:\Users\asannidhi\Desktop\LH sp ok 5"
#       5 od_images = r"C:\Users\asannidhi\Desktop\maskimg"
# ----> 6 for img,od in os.listdir(img_path), os.listdir(od_images):
#       8     image = cv.imread(img_path+"\\"+img, cv.IMREAD_GRAYSCALE)
#       9     od = cv.imread(od_images+"\\"+od, cv.IMREAD_GRAYSCALE)
#
# ValueError: too many values to unpack (expected 2)

# %%
import cv2 as cv
import os

img_path = r"C:\Users\asannidhi\Desktop\LH sp ok 5"
img_path2=r"C:\Users\asannidhi\Downloads\mask.png"
od = cv.imread(img_path2,cv.IMREAD_GRAYSCALE)
for img in os.listdir(img_path):
    image = cv.imread(img_path+"\\"+img, cv.IMREAD_GRAYSCALE)
    bitwiseAnd = cv.bitwise_or(image, od)
    #res =  cv.bitwise_and(image,image,mask = od)
    cv.imwrite( r"C:\Users\asannidhi\Downloads" + img+ "_masked.jpg", bitwiseAnd)

# %%
import cv2 as cv
import os

img_path = r"C:\Users\asannidhi\Desktop\LH sp ok 5"
img_path2=r"C:\Users\asannidhi\Downloads\mask.png"
od = cv.imread(img_path2)
#od_images = r"C:\Users\asannidhi\Desktop\maskimg"
for img in zip(os.listdir(img_path)):

    image = cv.imread(img_path+"\\"+str(img), cv.IMREAD_COLOR)
    #od = cv.imread(od_images+"\\"+od, cv.IMREAD_GRAYSCALE)
    #other = cv.bitwise_not(od)
    res =  cv.bitwise_or(image, od)

    cv.imwrite( r"C:\Users\asannidhi\Downloads" + img+ "_masking.jpg", res)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [90], in <cell line: 8>()
#      10 image = cv.imread(img_path+"\\"+str(img), cv.IMREAD_COLOR)
#      11 #od = cv.imread(od_images+"\\"+od, cv.IMREAD_GRAYSCALE)
#      12 #other = cv.bitwise_not(od)
# ---> 13 res =  cv.bitwise_or(image, od)
#      15 cv.imwrite( r"C:\Users\asannidhi\Downloads" + img+ "_masking.jpg", res)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'
