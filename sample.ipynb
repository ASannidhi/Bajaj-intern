# %%
from matplotlib import pyplot as plt
import cv2 as cv
img=cv.imread(r"C:\Users\asannidhi\Desktop\tempimg_mattred.png")
plt.imshow(img)
h,w = img.shape[:2]
print(h,w)
# Out:
# 600 800

# %%
crop=img[50:480,180:610]

# %%
plt.imshow(crop)
